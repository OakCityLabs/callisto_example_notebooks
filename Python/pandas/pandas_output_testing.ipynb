# %%
import io
import requests
import pandas as pd
import random
import string
from datetime import datetime, timedelta
import numpy as np
pd.options.display.html.table_schema = True
random.seed(1)

# %% [markdown]
# ## Random Generators
# Some functions to help generate data

# %%
def random_string(length=20):
    return ''.join(random.choice(string.ascii_letters) for i in range(length))

def random_number():
    return np.float64(random.random() * random.randint(1, 100))

def random_int():
    return random.randint(-10000, 10000)

def random_bool():
    return random.choice([True, False])

def random_timedelta():
    return np.timedelta64(random.randint(1, 1000000), 's')

def random_date():
    start = np.datetime64('1900-01-01')
    end = np.datetime64('2100-01-01')
    difference = (end - start).item().total_seconds()
    
    return start + np.timedelta64(
        random.randint(0, difference), 's'
    )
def random_category():
    return random.choice(["cat 1", "cat 2", "cat 3"])

# %% [markdown]
# ## Make some Tables

# %% [markdown]
# ### One of every data type:

# %%
total_rows = 20
data = {
    'integers': [random_int() for i in range(total_rows)],
    'floats': [random_number() for i in range(total_rows)],
    'booleans': [random_bool() for i in range(total_rows)],
    'datetimes': [random_date() for i in range(total_rows)],
    'timedeltas': [random_timedelta() for i in range(total_rows)],
    'strings': [random_string() for i in range(total_rows)],
    'category': [random_category() for i in range(total_rows)],
}
index = range(20)
df = pd.DataFrame(data, index=index)
df["category"] = df["category"].astype("category")
df
# Out:
#     integers     floats  booleans           datetimes       timedeltas  \
# 0      -5598   8.276148      True 1999-09-24 23:39:47  6 days 17:28:52
# 1       8651   3.605710     False 1963-11-17 00:44:24  2 days 10:12:27
# 2      -7933   1.875057     False 2078-02-03 08:24:54 11 days 10:05:25
# 3      -1642  26.529211     False 1978-09-10 06:43:25  6 days 03:00:38
# 4      -6137  37.756612     False 1988-01-30 07:23:04  5 days 00:24:42
# 5       6234  49.357977      True 2059-01-18 03:18:08  5 days 21:14:41
# 6       4728  12.636425     False 2066-12-27 09:15:51  9 days 20:54:21
# 7       5474  66.680858      True 2037-10-10 18:49:49  4 days 07:55:22
# 8       2439   6.992534     False 2063-04-04 06:46:09  5 days 00:42:36
# 9      -3121  66.331157     False 1974-08-19 01:16:40  4 days 04:48:10
# 10     -6925  17.464932      True 2091-02-23 19:55:15  0 days 00:27:42
# 11      5986  50.031358     False 2082-11-23 22:43:46  6 days 12:50:36
# 12     -9072  60.305614     False 1948-01-31 08:29:46  6 days 13:19:06
# 13      2773  11.988451      True 2023-10-27 04:00:33  7 days 13:36:17
# 14      4180  17.289283     False 1999-04-10 16:19:11  9 days 13:04:07
# 15      9904  13.759144      True 2088-04-27 14:01:43  7 days 10:23:23
# 16     -9931  69.112639      True 2053-09-10 07:02:39  4 days 00:27:03
# 17      4594  63.261397     False 1927-12-20 17:27:44  5 days 13:26:42
# 18     -1273  51.504232     False 2029-04-04 19:13:27  7 days 06:43:14
# 19     -2504  43.663684     False 2085-09-28 09:31:24  0 days 08:08:54
#
#                  strings category
# 0   ZoOlJLlfZJZqcRefbCaW    cat 1
# 1   WrprhZNlwsekkqHkQrPT    cat 3
# 2   sDSuFEhbtyvAYmqgqUGn    cat 2
# 3   MBbobzjcUkCTGRBIoOZS    cat 2
# 4   HCoHPbzRKZuQOBdVtind    cat 3
# 5   teettVkAKqiaJcLnKDkX    cat 2
# 6   TNGcymwgnKRBLmFgQysG    cat 3
# 7   FbuNzsbkmuZKYivBnrRg    cat 2
# 8   yJwRIFXIpeUcfikkInrW    cat 3
# 9   vMGqxvvhspMXTFiLJXgu    cat 2
# 10  cAeyYjivhNLYyeKJoKfr    cat 1
# 11  xsKIhDrgYcsaNQafAhYc    cat 2
# 12  mpYLAkhCkRpkVgByZIsJ    cat 2
# 13  qTEugnPucbaYsUMuCzuz    cat 1
# 14  eeuMDhqnYNXISEQwqlIn    cat 2
# 15  tmpxfrfWCfPKPvoytcul    cat 2
# 16  uYLtpvgINLZMfpobZpze    cat 1
# 17  rJeUebOasWYwFEjgGXYu    cat 3
# 18  eGQllXjjutgTGMsinjIU    cat 2
# 19  cXuNZRJVSnltBIkdTQpq    cat 3

# %% [markdown]
# ## Many columns:

# %%
total_rows_2 = 20
data_2 = {
    'strings1': [random_string(30) for i in range(total_rows_2)],
    'strings2': [random_string(30) for i in range(total_rows_2)],
    'strings3': [random_string(30) for i in range(total_rows_2)],
    'strings4': [random_string(30) for i in range(total_rows_2)],
    'strings5': [random_string(30) for i in range(total_rows_2)],
    'strings6': [random_string(30) for i in range(total_rows_2)],
    'strings7': [random_string(30) for i in range(total_rows_2)],
    'strings8': [random_string(30) for i in range(total_rows_2)],
    'strings9': [random_string(30) for i in range(total_rows_2)],
    'strings10': [random_string(30) for i in range(total_rows_2)],
    'strings11': [random_string(30) for i in range(total_rows_2)],
    'strings12': [random_string(30) for i in range(total_rows_2)],
    'strings13': [random_string(30) for i in range(total_rows_2)],
    'strings14': [random_string(30) for i in range(total_rows_2)],
    'strings15': [random_string(30) for i in range(total_rows_2)],
    'strings16': [random_string(30) for i in range(total_rows_2)],
    'strings17': [random_string(30) for i in range(total_rows_2)],
    'strings18': [random_string(30) for i in range(total_rows_2)],
    'strings19': [random_string(30) for i in range(total_rows_2)],
}
index_2 = range(total_rows_2)
df_2 = pd.DataFrame(data_2, index=index_2)
df_2
# Out:
#                           strings1                        strings2  \
# 0   bdSwLiLiiqrzKzlNfoFalHuGPCROUo  dUquViqYyZhRtgBpGJnvvGYzLEgiPC
# 1   puFREoTAvJNUPrPodeWGPxkGXYnttS  HJULSHIbsVkmxyHugAwiKectZPIuAt
# 2   tJxkSSVDMfhMGKyljqBnKUWYdFRzTO  uwruVVHGaHhjuUuYuKeCrEDxVyfLZd
# 3   wyGkIUcHfZqOgrVfiXNQRSfCpyZBzk  idHFKqYpSKVvxZPxztDMvIGkbjqRoK
# 4   uCiNFnhBMIAhQsrpyVJamHCLbbOMpq  ihlXAUNdZgIRrTgnqeOKHPfeYnPlGB
# 5   nlsjImrtLWqRCYZkIwFAhXnKynsZgZ  bLxFTZsomMFpBCRxImZEUeqAmaVIXy
# 6   bhKVaIsRWUPieGxKZtBGRwWHuahCTC  GFezNGYLLBcwDamtSSPaIhtGVuXIPK
#
#                          strings19
# 0   EFTRsdGDofPtPkCnrkItUzamKMEasO
# 1   VXqZJqeWycKJScmSEWnzutFNGqTZqM
# 2   kzzFZJopAMCeTWydaSmwmgScEmdQlu
# 3   cQGqnmZAHeKlqcjaTWYdLJnVluilSz
# 4   LXaaLvGPWbnfXVEDekrHbYAsLJLmlu
# 5   gUKsTtmKHharnnWpImFuzYMEUgxeDq
# 6   EUdbvESapJidzgodtNxggrrUjpIVMj
# 7   EdACTbavOBtFdUCuBObkrxpejNSuzI
# 8   ILTtWHWuxZFjNnAngWfkaObfDHKelw
# 9   HYJOllVAeDgaEXPxzUjLxiMpyumYHX
# 10  OIgtCnLRDjqdkmSFImczOwEGAomXOf
# 11  ajYFMTnFrzhGegwkmRBtAqXHOpyAcc
# 12  VUmxzuWArCTzliSBwTRxLXxGBcxWhv
# 13  dnVNwlJWLUsFJlBxxbklNwYSSEOCRI
# 14  mhuPVbBoCtArfJmChOcXSaIXKopcMF
# 15  QvnmhbSWtOrSgixCBvZWTdGtfDokKL
# 16  LnHsWLPKEsRrgJPqklHVMkBStzzokA
# 17  kJIvpnXjsTQeOeSphPtWaizzOdhMdi
# 18  DzspkEoOLoMqHWAZDLKSsiOQGZiciO
# 19  IjLaHqIJlTcwEIZNlouPWOlTnRlZKF

# %% [markdown]
# ## A Small DataFrame:

# %%
total_rows_3 = 5
data_3 = {
    'strings1': [random_string(5) for i in range(total_rows_3)],
    'strings2': [random_string(5) for i in range(total_rows_3)],
}
index_3 = range(total_rows_3)
df_3 = pd.DataFrame(data_3, index=index_3)
df_3
# Out:
#   strings1 strings2
# 0    QVpin    tZMxZ
# 1    cGvZp    wpnqm
# 2    zDTqT    kvrQV
# 3    lhcfc    uxcen
# 4    sFdhO    lzPDn

# %% [markdown]
# ## Many Rows:

# %%
total_rows_4 = 200
data_4 = {
    'strings1': [random_string() for i in range(total_rows_4)],
    'strings2': [random_string() for i in range(total_rows_4)],
}
index_4 = range(total_rows_4)
df_4 = pd.DataFrame(data_4, index=index_4)
df_4
# Out:
#                  strings1              strings2
# 0    NaDzywRxFMMaPqVeZQdz  XXZnTSSIdSIPhQgJIXhc
# 1    AxZTzltOmXNftbBcDazm  flVsAZdfhmMjCalmnnkU
# 2    INEYqbMSVnoRPiWMSvYp  axGWPbocNjkYhpZAjnPw
# 3    OqvcysbODbBbglQpbzMC  deRxstdnZEbfHcYfFnhO
# 4    jXenmWAKKSwxeUYomgiM  hbcOAXXChcbJaMqgRqtk
# ..                    ...                   ...
# 195  ZYldFBhlaQLcfDKBwmHd  cCXvUHsmbnKxvPFKTwgH
# 196  wEZWfxlXYypTfHqJLcKA  dgAAUbmyfIJDBhOnTeqg
# 197  jXGrBouBnJgnxIFJkWuy  QLSldiToKgJmsTZnsKMR
# 198  hoVzBDzNsSinubIeOfuB  BRMqlzuaxzhWcUplYlrt
# 199  dFNTHhaPDRpEQNsywqYI  HVQiTGxjDDTwEOToOTRZ
#
# [200 rows x 2 columns]
