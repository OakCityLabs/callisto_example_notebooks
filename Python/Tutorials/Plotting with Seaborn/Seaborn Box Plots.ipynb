# %% [markdown]
# # Statistical Relationships With Seaborn - Box Plots
# ### Use the **catplot()** function from the **Seaborn** library to visualize the distribution of your variables across categories.
# ### See more info at [https://seaborn.pydata.org/tutorial/relational.html](https://seaborn.pydata.org/tutorial/relational.html)

# %%
# %pip install -Uqq seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the Seaborn Library
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
# Download data from Seaborn
# If you get an SSL error when you try to load the dataset, uncomment the following 2 lines:
# import ssl
# ssl._create_default_https_context = ssl._create_unverified_context

diamonds = sns.load_dataset("diamonds")
tips = sns.load_dataset("tips")

# %% [markdown]
# # Box Plot

# %%
sns.catplot(x="day", y="total_bill", kind="box", data=tips)

# %% [markdown]
# # Box Plot with shape of distribution

# %%
sns.catplot(x="color", y="price", kind="boxen",
            data=diamonds.sort_values("color"))
