# %% [markdown]
# # 🐻 Callisto Features — **Data Explorer**
#
# ## Learn how to examine the data in your notebook with the **Data Explorer**.

# %% [markdown]
# Run each of the cells below to learn how the **Data Explorer** can work for you.
#
# Let's start with something simple.

# %%
a_var = "this can be equal to anything"
a_var
# Out:
# 'this can be equal to anything'

# %% [markdown]
# Open the **Data Explorer** to see the value of `a_var`.  You can open the **Data Explorer** in any of the following ways:
#
#
# - On Mac
#    - Go to the **Tools** menu then choose **Data Explorer**
#    - Use the **Data Explorer** toolbar button on in the top right of the notebook view. ↗️
# - On iPad
#    - Open the **Tools** menu under the hammer icon (🔨) and choose **Data Explorer**

# %% [markdown]
# Let's update our variable!  Run the next cell to see the `a_var` update in the **Data Explorer**.

# %%
a_var = "I've updated this variable 😂 " 
a_var
# Out:
# The window should have the new value for "a_var"

# %% [markdown]
# Now let's do something a bit more fun!

# %%
words = ["this", "is", "my", "word", "list"]
fruits = {"apple 🍎": 5, "oranges 🍊": 4, "bananas 🍌": 2, "blueberries 🫐": "32 oz"}
fruits
# Out:
# {'apple 🍎': 5, 'oranges 🍊': 4, 'bananas 🍌': 2, 'blueberries 🫐': '32 oz'}

# %% [markdown]
# Check out the detailed info for these data structures by clicking on the ℹ️ icon for each entry

# %% [markdown]
# Updating your variables will also update them in the **Data Explorer**.
#
# Run the next cell and watch the values update in the **Data Explorer**.

# %%
words.append("updated")
fruits["apple 🍎"] = 50
fruits
# Out:
# {'apple 🍎': 50, 'oranges 🍊': 4, 'bananas 🍌': 2, 'blueberries 🫐': '32 oz'}

# %% [markdown]
# ## Exporting data
#
# When looking at the detailed view of a data entry, on the top right there will be two buttons: CSV and copy
#
# Use these to export your data into other applications, like Excel, Numbers, Word and Mail.
#
# Try it out!
