# %% [markdown]
# # Welcome to Callisto 🐻
#
# ### The Data Science Development Environment
#
# ### This Notebook with help you learn how to explore the data in your running notebook

# %%
# Lets start with something simple. 

# Run this cell

a_var = "this can be equal to anything"

print("I've made a_var! \n \n")

print("Click or tap on \"Data Explorer\" in the top right \n \n")

print("\"a_var\" should be an entry in the Data Explorer window")
# Out:
# I've made a_var!
#
#
# Click or tap on "Data Explorer" in the top right
#
#
# "a_var" should be an entry in the Data Explorer window

# %%
## Let's update our variable

# Run this cell

a_var = "I've updated this variable 😂 " 

print("The window should have the new value for \"a_var\"")
# Out:
# The window should have the new value for "a_var"

# %%
# Let's do something a bit more fun

# Run this cell

words = ["this", "is", "my", "word", "list"]

fruits = {"apple 🍎": 5, "oranges 🍊": 4, "bananas 🍌": 2, "blueberries 🫐": "32 oz"}


print("words and fruits are made")

print("Check out the detailed info for these data structures by clicking on the ℹ️ icon for each entry")
# Out:
# words and fruits are made
# Check out the detailed info for these data structures by clicking on the ℹ️ icon for each entry

# %%
## Run this cell

print("Updating your variables will also update them in the data explorer")

fruits["apple 🍎"] = 50

words.append("updated")

print("updated the lists! Make sure they are updated in the Data Explorer!")
# Out:
# Updating your variables will also update them in the data explorer
# updated the lists! Make sure they are updated in the Data Explorer!

# %% [markdown]
# ## Exporting data
#
# #### When looking at the detailed view of a data entry, on the top right there will be two buttons: CSV and copy
#
# #### Use these to export your data into other applications.
#
# #### Try it out!
